# %%
def generate_story(theme, region, language, length):
    story = f"This is a {length} cultural story from {region} based on the theme '{theme}'."
    return story

# Example usage
generate_story("Festival", "India", "English", "Short")
# Out:
# "This is a Short cultural story from India based on the theme 'Festival'."

# %% [markdown]
# ## Problem Definition & Objective
# Cultural stories are often not easily accessible in a structured digital format.
# The objective of this project is to generate culturally relevant stories using AI
# based on user inputs such as theme, region, language, and story length.

# %% [markdown]
# ## Selected Project Track
# AI Applications – Generative AI (Text Generation)

# %% [markdown]
# ## Data Understanding & Preparation
# This project does not use a fixed dataset.
# Stories are generated dynamically using prompt-based AI generation
# based on user-provided inputs.

# %% [markdown]
# ## Ethical Considerations & Responsible AI
# The system is designed to avoid offensive or biased content.
# Cultural sensitivity is considered while generating stories.
